# %%
import pandas as pd

# %%
df = pd.read_csv('data/data.csv', index_col=0)
df
# Out:
#       CO(mg/m^3)  Delta CO(mg/m^3)  People  Suction Pump  Temperature(°C)  \
# 0            4.8               1.9     7.0      0.000000        10.412500
# 1            6.9               2.1     5.0      0.000000        10.262500
# 2            6.1              -0.8     0.0      0.301323        10.166667
# 3            3.9              -2.2     0.0      1.000000        10.087500
# 4            1.5              -2.4     0.0      0.717769         9.962500
# ...          ...               ...     ...           ...              ...
# 9328         3.1              -0.8     0.0      0.450891        18.700000
# 9329         2.4              -0.7     0.0      0.348074        18.712500
# 9330         2.4               0.0     0.0      0.099655        18.729167
# 9331         2.1              -0.3     1.0      0.000000        18.712500
# 9332         2.2               0.1     0.0      0.084474        18.712500
#
#       Relative Humidity(%)  Absolute Humidity(g/m^3)
# 0                62.208333                  0.779629
# 1                63.108333                  0.784062
# 2                63.683333                  0.786692
# 3                63.850000                  0.784825
# 4                64.008333                  0.780729
# ...                    ...                       ...
# 9328             37.941667                  0.694262
# 9329             38.125000                  0.700287
# 9330             38.204167                  0.703671
# 9331             38.195833                  0.702992
# 9332             38.195833                  0.703100
#
# [9333 rows x 7 columns]

# %%
# for every column except the first two, create the shift of 1 to 6
for col in df.columns[:]:
    for i in range(1, 7):
        if col in list(df.columns[2:]):
            df[f'{col}_lag_{i}'] = df[col].shift(-i)
        #if col in list(df.columns[:]):
        df[f'{col}_prev_{i}'] = df[col].shift(i)

for col in df.columns[:2]:
    for i in range(1, 7):
        df[f'{col}_lag_{i}'] = df[col].shift(-i)
df.dropna(inplace=True)
df
# Out:
#       CO(mg/m^3)  Delta CO(mg/m^3)  People  Suction Pump  Temperature(°C)  \
# 6           1.70              0.70     0.0      0.103795         9.712500
# 7           1.90              0.20     0.0      0.369293         9.587500
# 8           1.40             -0.50     0.0      0.408798         9.437500
# 9           0.80             -0.60     0.0      0.243703         9.300000
# 10          0.70             -0.10     0.0      0.122082         9.133333
# ...          ...               ...     ...           ...              ...
# 9322        0.45              0.05     0.0      0.122082        18.566667
# 9323        0.50              0.05     0.0      0.063255        18.600000
# 9324        1.10              0.60     4.0      0.000000        18.616667
# 9325        4.00              2.90     8.0      0.000000        18.650000
# 9326        5.00              1.00     9.0      0.000000        18.650000
#
#       Relative Humidity(%)  Absolute Humidity(g/m^3)  CO(mg/m^3)_prev_1  \
# 6                64.145833                  0.770913               1.00
# 7                64.133333                  0.765104               1.70
# 8                64.220833                  0.759387               1.90
# 9                64.308333                  0.754154               1.40
# 10               64.533333                  0.749083               0.80
# ...                    ...                       ...                ...
# 9322             35.904167                  0.658025               0.40
# 9323             36.275000                  0.664142               0.45
# 9324             36.720833                  0.670212               0.50
# 9325             37.104167                  0.676096               1.10
# 9326             37.475000                  0.681867               4.00
#
#       CO(mg/m^3)_prev_2  CO(mg/m^3)_prev_3  ...  CO(mg/m^3)_lag_3  \
# 6                  1.50               3.90  ...               0.8
# 7                  1.00               1.50  ...               0.7
# 8                  1.70               1.00  ...               0.6
# 9                  1.90               1.70  ...               0.8
# 10                 1.40               1.90  ...               1.4
# ...                 ...                ...  ...               ...
# 9322               0.50               0.60  ...               4.0
# 9323               0.40               0.50  ...               5.0
# 9324               0.45               0.40  ...               3.9
# 9325               0.50               0.45  ...               3.1
# 9326               1.10               0.50  ...               2.4
#
#       CO(mg/m^3)_lag_4  CO(mg/m^3)_lag_5  CO(mg/m^3)_lag_6  \
# 6                  0.7              0.60              0.80
# 7                  0.6              0.80              1.40
# 8                  0.8              1.40              4.40
# 9                  1.4              4.40              3.75
# 10                 4.4              3.75              3.10
# ...                ...               ...               ...
# 9322               5.0              3.90              3.10
# 9323               3.9              3.10              2.40
# 9324               3.1              2.40              2.40
# 9325               2.4              2.40              2.10
# 9326               2.4              2.10              2.20
#
#       Delta CO(mg/m^3)_lag_1  Delta CO(mg/m^3)_lag_2  Delta CO(mg/m^3)_lag_3  \
# 6                       0.20                    -0.5                    -0.6
# 7                      -0.50                    -0.6                    -0.1
# 8                      -0.60                    -0.1                    -0.1
# 9                      -0.10                    -0.1                     0.2
# 10                     -0.10                     0.2                     0.6
# ...                      ...                     ...                     ...
# 9322                    0.05                     0.6                     2.9
# 9323                    0.60                     2.9                     1.0
# 9324                    2.90                     1.0                    -1.1
# 9325                    1.00                    -1.1                    -0.8
# 9326                   -1.10                    -0.8                    -0.7
#
#       Delta CO(mg/m^3)_lag_4  Delta CO(mg/m^3)_lag_5  Delta CO(mg/m^3)_lag_6
# 6                       -0.1                   -0.10                    0.20
# 7                       -0.1                    0.20                    0.60
# 8                        0.2                    0.60                    3.00
# 9                        0.6                    3.00                   -0.65
# 10                       3.0                   -0.65                   -0.65
# ...                      ...                     ...                     ...
# 9322                     1.0                   -1.10                   -0.80
# 9323                    -1.1                   -0.80                   -0.70
# 9324                    -0.8                   -0.70                    0.00
# 9325                    -0.7                    0.00                   -0.30
# 9326                     0.0                   -0.30                    0.10
#
# [9321 rows x 91 columns]

# %%
list(df.columns)
# Out:
# ['CO(mg/m^3)',
#  'Delta CO(mg/m^3)',
#  'People',
#  'Suction Pump',
#  'Temperature(°C)',
#  'Relative Humidity(%)',
#  'Absolute Humidity(g/m^3)',
#  'CO(mg/m^3)_prev_1',
#  'CO(mg/m^3)_prev_2',
#  'CO(mg/m^3)_prev_3',
#  'CO(mg/m^3)_prev_4',
#  'CO(mg/m^3)_prev_5',
#  'CO(mg/m^3)_prev_6',
#  'Delta CO(mg/m^3)_prev_1',
#  'Delta CO(mg/m^3)_prev_2',
#  'Delta CO(mg/m^3)_prev_3',
#  'Delta CO(mg/m^3)_prev_4',
#  'Delta CO(mg/m^3)_prev_5',
#  'Delta CO(mg/m^3)_prev_6',
#  'People_lag_1',
#  'People_prev_1',
#  'People_lag_2',
#  'People_prev_2',
#  'People_lag_3',
#  'People_prev_3',
#  'People_lag_4',
#  'People_prev_4',
#  'People_lag_5',
#  'People_prev_5',
#  'People_lag_6',
#  'People_prev_6',
#  'Suction Pump_lag_1',
#  'Suction Pump_prev_1',
#  'Suction Pump_lag_2',
#  'Suction Pump_prev_2',
#  'Suction Pump_lag_3',
#  'Suction Pump_prev_3',
#  'Suction Pump_lag_4',
#  'Suction Pump_prev_4',
#  'Suction Pump_lag_5',
#  'Suction Pump_prev_5',
#  'Suction Pump_lag_6',
#  'Suction Pump_prev_6',
#  'Temperature(°C)_lag_1',
#  'Temperature(°C)_prev_1',
#  'Temperature(°C)_lag_2',
#  'Temperature(°C)_prev_2',
#  'Temperature(°C)_lag_3',
#  'Temperature(°C)_prev_3',
#  'Temperature(°C)_lag_4',
#  'Temperature(°C)_prev_4',
#  'Temperature(°C)_lag_5',
#  'Temperature(°C)_prev_5',
#  'Temperature(°C)_lag_6',
#  'Temperature(°C)_prev_6',
#  'Relative Humidity(%)_lag_1',
#  'Relative Humidity(%)_prev_1',
#  'Relative Humidity(%)_lag_2',
#  'Relative Humidity(%)_prev_2',
#  'Relative Humidity(%)_lag_3',
#  'Relative Humidity(%)_prev_3',
#  'Relative Humidity(%)_lag_4',
#  'Relative Humidity(%)_prev_4',
#  'Relative Humidity(%)_lag_5',
#  'Relative Humidity(%)_prev_5',
#  'Relative Humidity(%)_lag_6',
#  'Relative Humidity(%)_prev_6',
#  'Absolute Humidity(g/m^3)_lag_1',
#  'Absolute Humidity(g/m^3)_prev_1',
#  'Absolute Humidity(g/m^3)_lag_2',
#  'Absolute Humidity(g/m^3)_prev_2',
#  'Absolute Humidity(g/m^3)_lag_3',
#  'Absolute Humidity(g/m^3)_prev_3',
#  'Absolute Humidity(g/m^3)_lag_4',
#  'Absolute Humidity(g/m^3)_prev_4',
#  'Absolute Humidity(g/m^3)_lag_5',
#  'Absolute Humidity(g/m^3)_prev_5',
#  'Absolute Humidity(g/m^3)_lag_6',
#  'Absolute Humidity(g/m^3)_prev_6',
#  'CO(mg/m^3)_lag_1',
#  'CO(mg/m^3)_lag_2',
#  'CO(mg/m^3)_lag_3',
#  'CO(mg/m^3)_lag_4',
#  'CO(mg/m^3)_lag_5',
#  'CO(mg/m^3)_lag_6',
#  'Delta CO(mg/m^3)_lag_1',
#  'Delta CO(mg/m^3)_lag_2',
#  'Delta CO(mg/m^3)_lag_3',
#  'Delta CO(mg/m^3)_lag_4',
#  'Delta CO(mg/m^3)_lag_5',
#  'Delta CO(mg/m^3)_lag_6']

# %%
df.to_csv('data/data_lagged.csv')
